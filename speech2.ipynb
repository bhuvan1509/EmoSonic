# %%
#hackersrelams.net website 


import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio
import warnings
warnings.filterwarnings('ignore')
paths = []
labels = []
for dirname, _, filenames in os.walk('C:\\Users\\Bhuvan raju\\Downloads\\archive (1)\\TESS Toronto emotional speech set data'):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('_')[-1]
        label = label.split('.')[0]
        labels.append(label.lower())
    if len(paths) == 2800:
        break
print('Dataset is Loaded')
len(paths)
paths[:5]
labels[:5]
## Create a dataframe
df = pd.DataFrame()
df['speech'] = paths
df['label'] = labels
df.head()
df['label'].value_counts()
# Convert label column to categorical data
df['label'] = pd.Categorical(df['label'])

# Plot countplot
sns.countplot(data=df, x='label')
plt.show()

import matplotlib.pyplot as plt
import librosa.display

def waveplot(data, sr, emotion):
    plt.figure(figsize=(10, 4))
    plt.title(emotion, size=20)
    librosa.display.waveshow(data, sr=sr)
    plt.show()

def spectogram(data, sr, emotion):
    x = librosa.stft(data)
    xdb = librosa.amplitude_to_db(abs(x))
    plt.figure(figsize=(11,4))
    plt.title(emotion, size=20)
    librosa.display.specshow(xdb, sr=sr, x_axis='time', y_axis='hz')
    plt.colorbar()
    return xdb  # Return the spectrogram data

emotion = 'fear'  # Define the emotion variable
path = np.array(df['speech'][df['label'] == emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
emotion = 'angry'
path = np.array(df['speech'][df['label']==emotion])[1]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)

emotion = 'disgust'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)

emotion = 'neutral'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)

emotion = 'sad'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)

emotion = 'ps'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)

emotion = 'happy'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)

def extract_mfcc(filename):
     y, sr = librosa.load(filename, duration=3, offset=0.5)
     mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)
     return mfcc
print(extract_mfcc(df['speech'][0]))
X_mfcc = df['speech'].apply(lambda x: extract_mfcc(x))
print(X_mfcc)
X = [x for x in X_mfcc]
X = np.array(X)
print(X.shape)
## input split
X = np.expand_dims(X, -1)
print(X.shape)
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
y = enc.fit_transform(df[['label']])
y = y.toarray()
print(y.shape)
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

model = Sequential([
    LSTM(256, return_sequences=False, input_shape=(40,1)),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(7, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()

# Train the model and assign the history object

history = model.fit(X, y, validation_split=0.2, epochs=50, batch_size=64)

# Plot the training and validation accuracy
epochs = list(range(50))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, label='train accuracy')
plt.plot(epochs, val_acc, label='val accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()


loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, loss, label='train loss')
plt.plot(epochs, val_loss, label='val loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
# Out:
# Dataset is Loaded
# [-3.96986206e+02  7.74405365e+01 -1.95927906e+01 -2.16666889e+01
#  -2.11275506e+00  1.00753632e+01 -2.03667068e+01 -6.09244919e+00
#  -7.21228361e+00 -5.57365894e-01 -1.83255327e+00  2.02101514e-01
#   7.27551103e-01  1.31773770e+00  2.88633752e+00  2.85579133e+00
#  -4.71292162e+00 -4.43651056e+00 -1.62115920e+00 -1.02398405e+01
#  -7.55126143e+00 -1.79688025e+00 -7.03765202e+00  9.43658447e+00
#   8.35585499e+00  2.17123604e+01  1.92169895e+01  2.03489265e+01
#   1.34133663e+01  8.33917141e+00  3.94722402e-01  5.11131477e+00
#   9.56873894e+00  5.45486784e+00  2.50996375e+00 -1.82390714e+00
#   4.86896276e+00  9.31392384e+00  2.08915019e+00 -1.90649128e+00]
# 0       [-396.9862, 77.44054, -19.59279, -21.666689, -...
# 1       [-465.73267, 98.77373, 0.65600896, -32.74544, ...
# 2       [-429.79196, 46.124, 1.5550478, -0.21709539, 2...
# 3       [-403.46118, 76.32369, -12.531774, -22.288858,...
# 4       [-434.05756, 77.4455, 10.8655, 16.092943, 8.04...
#                               ...
# 2795    [-553.2201, 89.83577, 27.215466, 16.407124, 19...
# 2796    [-589.23676, 96.20408, 36.96118, 15.014448, 28...
# 2797    [-533.41815, 85.43242, 27.791998, 19.307178, 2...
# 2798    [-548.6142, 110.16424, 31.910236, 12.572517, 2...
# 2799    [-549.2962, 102.374565, 32.268833, 26.261616, ...
# Name: speech, Length: 2800, dtype: object
# (2800, 40)
# (2800, 40, 1)
# (2800, 7)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                        │ (None, 256)                 │         264,192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_12 (Dropout)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_13 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_14 (Dropout)                 │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 7)                   │             455 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 305,799 (1.17 MB)
#  Trainable params: 305,799 (1.17 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 12s 164ms/step - accuracy: 0.4957 - loss: 1.3844 - val_accuracy: 0.7714 - val_loss: 0.7549
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - accuracy: 0.8067 - loss: 0.4847 - val_accuracy: 0.9357 - val_loss: 0.2120
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 132ms/step - accuracy: 0.9191 - loss: 0.2569 - val_accuracy: 0.9446 - val_loss: 0.1737
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 132ms/step - accuracy: 0.9537 - loss: 0.1460 - val_accuracy: 0.9625 - val_loss: 0.0918
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 132ms/step - accuracy: 0.9655 - loss: 0.1114 - val_accuracy: 0.9732 - val_loss: 0.0844
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 132ms/step - accuracy: 0.9745 - loss: 0.0846 - val_accuracy: 0.9661 - val_loss: 0.0841
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9732 - loss: 0.0910 - val_accuracy: 0.9768 - val_loss: 0.0662
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.9887 - loss: 0.0577 - val_accuracy: 0.9893 - val_loss: 0.0344
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 135ms/step - accuracy: 0.9860 - loss: 0.0448 - val_accuracy: 0.9786 - val_loss: 0.0733
# Epoch 10/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - accuracy: 0.9889 - loss: 0.0389 - val_accuracy: 0.9839 - val_loss: 0.0460
# Epoch 11/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 132ms/step - accuracy: 0.9808 - loss: 0.0678 - val_accuracy: 0.9857 - val_loss: 0.0468
# Epoch 12/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - accuracy: 0.9845 - loss: 0.0564 - val_accuracy: 0.9625 - val_loss: 0.0852
# Epoch 13/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 130ms/step - accuracy: 0.9812 - loss: 0.0538 - val_accuracy: 0.9929 - val_loss: 0.0193
# Epoch 14/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 130ms/step - accuracy: 0.9851 - loss: 0.0541 - val_accuracy: 0.9714 - val_loss: 0.0728
# Epoch 15/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 130ms/step - accuracy: 0.9841 - loss: 0.0595 - val_accuracy: 0.9875 - val_loss: 0.0383
# Epoch 16/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - accuracy: 0.9899 - loss: 0.0399 - val_accuracy: 0.9964 - val_loss: 0.0096
# Epoch 17/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 128ms/step - accuracy: 0.9962 - loss: 0.0128 - val_accuracy: 0.9929 - val_loss: 0.0202
# Epoch 18/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 130ms/step - accuracy: 0.9879 - loss: 0.0431 - val_accuracy: 0.9911 - val_loss: 0.0227
# Epoch 19/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 129ms/step - accuracy: 0.9931 - loss: 0.0306 - val_accuracy: 0.9821 - val_loss: 0.0637
# Epoch 20/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 130ms/step - accuracy: 0.9931 - loss: 0.0335 - val_accuracy: 0.9911 - val_loss: 0.0242
# Epoch 21/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - accuracy: 0.9917 - loss: 0.0343 - val_accuracy: 0.9536 - val_loss: 0.1676
# Epoch 22/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 130ms/step - accuracy: 0.9849 - loss: 0.0574 - val_accuracy: 0.9982 - val_loss: 0.0048
# Epoch 23/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 130ms/step - accuracy: 0.9949 - loss: 0.0205 - val_accuracy: 0.9982 - val_loss: 0.0025
# Epoch 24/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 128ms/step - accuracy: 0.9958 - loss: 0.0171 - val_accuracy: 0.9929 - val_loss: 0.0311
# Epoch 25/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 129ms/step - accuracy: 0.9874 - loss: 0.0448 - val_accuracy: 0.9929 - val_loss: 0.0166
# Epoch 26/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - accuracy: 0.9871 - loss: 0.0441 - val_accuracy: 0.9929 - val_loss: 0.0158
# Epoch 27/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 129ms/step - accuracy: 0.9915 - loss: 0.0243 - val_accuracy: 0.9768 - val_loss: 0.0843
# Epoch 28/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 130ms/step - accuracy: 0.9871 - loss: 0.0491 - val_accuracy: 0.9839 - val_loss: 0.0334
# Epoch 29/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 127ms/step - accuracy: 0.9986 - loss: 0.0120 - val_accuracy: 0.9804 - val_loss: 0.0938
# Epoch 30/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 129ms/step - accuracy: 0.9943 - loss: 0.0343 - val_accuracy: 0.9982 - val_loss: 0.0084
# Epoch 31/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 132ms/step - accuracy: 0.9927 - loss: 0.0239 - val_accuracy: 0.9964 - val_loss: 0.0112
# Epoch 32/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 129ms/step - accuracy: 0.9950 - loss: 0.0152 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 33/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 130ms/step - accuracy: 0.9997 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 34/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - accuracy: 0.9991 - loss: 0.0034 - val_accuracy: 0.9964 - val_loss: 0.0044
# Epoch 35/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 130ms/step - accuracy: 0.9960 - loss: 0.0105 - val_accuracy: 1.0000 - val_loss: 5.1962e-04
# Epoch 36/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 129ms/step - accuracy: 0.9991 - loss: 0.0064 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 37/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 130ms/step - accuracy: 0.9882 - loss: 0.0357 - val_accuracy: 0.9875 - val_loss: 0.0346
# Epoch 38/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - accuracy: 0.9952 - loss: 0.0106 - val_accuracy: 0.9911 - val_loss: 0.0174
# Epoch 39/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 130ms/step - accuracy: 0.9988 - loss: 0.0040 - val_accuracy: 1.0000 - val_loss: 2.4662e-04
# Epoch 40/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 128ms/step - accuracy: 1.0000 - loss: 7.5548e-04 - val_accuracy: 1.0000 - val_loss: 2.8629e-04
# Epoch 41/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - accuracy: 1.0000 - loss: 5.2672e-04 - val_accuracy: 1.0000 - val_loss: 1.6434e-04
# Epoch 42/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - accuracy: 1.0000 - loss: 3.5617e-04 - val_accuracy: 1.0000 - val_loss: 8.1610e-05
# Epoch 43/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 128ms/step - accuracy: 1.0000 - loss: 3.9278e-04 - val_accuracy: 1.0000 - val_loss: 4.8594e-05
# Epoch 44/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 128ms/step - accuracy: 1.0000 - loss: 2.7685e-04 - val_accuracy: 1.0000 - val_loss: 3.3616e-05
# Epoch 45/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 128ms/step - accuracy: 1.0000 - loss: 4.4979e-04 - val_accuracy: 1.0000 - val_loss: 2.6176e-05
# Epoch 46/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - accuracy: 1.0000 - loss: 1.8403e-04 - val_accuracy: 1.0000 - val_loss: 2.2815e-05
# Epoch 47/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 130ms/step - accuracy: 1.0000 - loss: 2.0715e-04 - val_accuracy: 1.0000 - val_loss: 2.0607e-05
# Epoch 48/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 132ms/step - accuracy: 1.0000 - loss: 2.7984e-04 - val_accuracy: 1.0000 - val_loss: 2.2742e-05
# Epoch 49/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - accuracy: 1.0000 - loss: 1.5204e-04 - val_accuracy: 1.0000 - val_loss: 2.2227e-05
# Epoch 50/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - accuracy: 1.0000 - loss: 9.1861e-05 - val_accuracy: 1.0000 - val_loss: 1.8103e-05
